# %%
import numpy as np

# %% [markdown]
# ## paper_code_1017_RNN_LSTM_GRU_CALCE 的 平均值

# %% [markdown]
# ### RNN

# %%
re_s = [0.02958776763089975,0.0385037112745739,0.021546255217576533,0.06600661404643682,0.039315200274727395,
        0.03291753089714841,0.03127628940139715,0.06325000279356961,0.0433508838663982,0.050722030197308324]

mae_s = [0.02917612372824167,0.029700749986033746,0.02474356533283969,0.034500770416393024,0.02838925651472371,
         0.026638836367756696,0.025202971476450717,0.03665769886866462,0.03268519687220779,0.03306143602863426]

rmse_s = [0.03895845930774464,0.03751671786170165,0.03157996696785486,0.04285304420415538,0.035364001226022374,
          0.03404083615980687,0.03221376828467158,0.04371476090158704,0.04080720140172504,0.04118981196330384]

r2_s = [0.9650364804724234,0.9674122354693349,0.9770761034061445,0.958490665428325,0.9727999610919579,
        0.9747675556776454,0.976106111956056,0.9549957903981618,0.9640504426276055,0.958185723959784]

print(f're mean: {np.array(re_s).mean()}')
print(f'mae mean: {np.array(mae_s).mean()}')
print(f'rmse mean: {np.array(rmse_s).mean()}')
print(f'r2 mean: {np.array(r2_s).mean()}')
# Out:
# re mean: 0.041647628560003605
# mae mean: 0.030075660559194594
# rmse mean: 0.03782385682785733
# r2 mean: 0.966892107048744

# %% [markdown]
# ### LSTM

# %%
re_s = [0.013928150733513398,0.012870076935348421,0.021068032298889202,0.010952896607973824,0.009631921257308221,
       0.014017838179996092,0.009206090291356831,0.013234029781552276,0.011072646496249682,0.011615485934546366]

mae_s = [0.021738169359200858,0.021479441812211425,0.020405705668845146,0.02187433598910518,0.02121529974611034,
         0.02099652940559,0.02166221199836009,0.021026955142482928,0.02184888096815074,0.020226528473588055]

rmse_s = [0.028784769853868648,0.02847046151622288,0.027438249035023895,0.02870548196094836,0.02813399991633775,
         0.02791893877415624,0.028597566327105278,0.02786622677331705,0.02837968505320175,0.027017509925249976]

r2_s = [0.9812837706265691,0.9818502553920926,0.9832517873468903,0.9813944092274113,0.9821397238347254,
       0.9824352723464597,0.9816886396259554,0.9825436685933581,0.9816675854272194,0.983563574316804]

print(f're mean: {np.array(re_s).mean()}')
print(f'mae mean: {np.array(mae_s).mean()}')
print(f'rmse mean: {np.array(rmse_s).mean()}')
print(f'r2 mean: {np.array(r2_s).mean()}')
# Out:
# re mean: 0.01275971685167343
# mae mean: 0.021247405856364476
# rmse mean: 0.028131288913543183
# r2 mean: 0.9821818686737485

# %% [markdown]
# ### GRU

# %%
re_s = [0.020207944886956722,0.015575768842543115,0.01572411198901672,0.017592137377504986,0.020705351685020496,
       0.014855023694876457,0.016916128039914175,0.01394479316428829,0.0170664329518335,0.01925718184877219]

mae_s = [0.022887412390660188,0.022396677355732517,0.022147937150256883,0.022878431176773538,0.02276573402690402,
        0.022497516654850377,0.02326389632866021,0.023120665002399565,0.022635760974750292,0.021951737219060297]

rmse_s = [0.029913921488464033,0.029394457908464,0.029038270991410053,0.029593851772891464,0.02970772369224438,
         0.03012191353576647,0.030183230631351997,0.030135313530864793,0.029547384429030463,0.02898505105090271]

r2_s = [0.9795352858349672,0.9803956346762064,0.9809031132797922,0.9799663123172274,0.9798377580893144,
       0.9795349135756382,0.9792183730573457,0.9794241319689392,0.9802262584744024,0.9809290477178367]

print(f're mean: {np.array(re_s).mean()}')
print(f'mae mean: {np.array(mae_s).mean()}')
print(f'rmse mean: {np.array(rmse_s).mean()}')
print(f'r2 mean: {np.array(r2_s).mean()}')
# Out:
# re mean: 0.017184487448072668
# mae mean: 0.022654576828004785
# rmse mean: 0.029662111903139037
# r2 mean: 0.979997082899167

# %% [markdown]
# ## paper_code_1016_卡尔曼滤波_TransformerEncoder_16-16_RCNN_CALCE 的 平均值

# %% [markdown]
# ### num_epcho = 500

# %%
re_s = [0.03151851942325445,0.053388384633652246,0.03497474644536741,0.03036784256006517,0.03313049357930012,
       0.04532476583276375,0.034080700090377294,0.012659374665301218,0.0325384992021171,0.021413263801871203]

mae_s = [0.023669069349662845,0.021457564137882953,0.021605648301904982,0.02690793616022015,0.024012627438345414,
        0.02087407681132512,0.02132867089373034,0.020766492036181954,0.019210664932795284,0.03219394286564081]

rmse_s = [0.030433914921319277,0.03017289890876028,0.02808046247158403,0.03351401847974694,0.030219581851168832,
         0.028091534249215518,0.028340294604196955,0.02884104090227322,0.026082680590688224,0.05063564287457095]

r2_s = [0.9796562724450355,0.9801773979801692,0.9830890207628855,0.9754003060752983,0.9807458028310929,
       0.9828870229635367,0.9830442471845153,0.9822810721522582,0.9853413313773299,0.9096001705818285]

print(f're mean: {np.array(re_s).mean()}')
print(f'mae mean: {np.array(mae_s).mean()}')
print(f'rmse mean: {np.array(rmse_s).mean()}')
print(f'r2 mean: {np.array(r2_s).mean()}')

print()
print(f're mean: {np.array(re_s).min()}')
print(f'mae mean: {np.array(mae_s).min()}')
print(f'rmse mean: {np.array(rmse_s).min()}')
print(f'r2 mean: {np.array(r2_s).min()}')
# Out:
# re mean: 0.032939659023406995
# mae mean: 0.023202669292768985
# rmse mean: 0.031441206985352424
# r2 mean: 0.974222264435395
#
# re mean: 0.012659374665301218
# mae mean: 0.019210664932795284
# rmse mean: 0.026082680590688224
# r2 mean: 0.9096001705818285

# %% [markdown]
# ## paper_code_0911_RNN_LSTM_GRU_NASA 的 平均值

# %% [markdown]
# ### RNN

# %%
re_s = [0.11074209259076577,0.09889422321601467,0.07967146390743116,0.11312427155378718,0.11880660871979803,
       0.1030721705230929,0.09879100763977947,0.097301232375712,0.1103438448806901,0.12388061337454649]

mae_s = [0.03681622008740275,0.030964597625894975,0.030103972922868108,0.03529910846150134,0.03756083684786255,
        0.035155083341923805,0.036911181966631,0.0340415630367971,0.03683237849196433,0.03670632780751534]

rmse_s = [0.04436574670473149,0.04007921399612527,0.03954236053167044,0.04378818090971108,0.04608387470877305,
         0.043112970541383744,0.044978166045651524,0.04216092978875057,0.04504943037245918,0.04508118874024529]

r2_s = [0.9321613049409102,0.94037641013532,0.9418818011416819,0.932587575088216,0.9275048363097043,
       0.9350849115723234,0.9307474553521191,0.9359182024953515,0.9300792430413871,0.9286519458662188]

print(f're mean: {np.array(re_s).mean()}')
print(f'mae mean: {np.array(mae_s).mean()}')
print(f'rmse mean: {np.array(rmse_s).mean()}')
print(f'r2 mean: {np.array(r2_s).mean()}')
# Out:
# re mean: 0.10546275287816179
# mae mean: 0.03503912705903613
# rmse mean: 0.04342420623395017
# r2 mean: 0.9334993685943234

# %% [markdown]
# ### LSTM

# %%
re_s = [0.1846608865943975,0.1529417352639213,0.193558969457612,0.05304088976153404,0.14946437509819183,
       0.15602450136829146,0.053483023321239755,0.15500492305127359,0.1572307582994073,0.1525581021487108]

mae_s = [0.056598834325870886,0.05119471785552778,0.05179131303807813,0.04173046861135447,0.05154210618017129,
        0.05232774040568649,0.034316233580416494,0.046681476455074596,0.04965742373096635,0.05300006875494388]

rmse_s = [0.06508776429047791,0.06120668538418938,0.06218432899977038,0.04979049084870114,0.06162349454438458,
         0.06325531033805497,0.04170147177539109,0.05582880064636024,0.05913660652829919,0.06252316850916924]

r2_s = [0.8542280074991759,0.8740411380336139,0.8709842618763421,0.914527702401464,0.8725633898735021,
       0.8622540203824053,0.9352030070894986,0.8957652929716406,0.8832114935310138,0.8590639148748016]

print(f're mean: {np.array(re_s).mean()}')
print(f'mae mean: {np.array(mae_s).mean()}')
print(f'rmse mean: {np.array(rmse_s).mean()}')
print(f'r2 mean: {np.array(r2_s).mean()}')
# Out:
# re mean: 0.14079681643645794
# mae mean: 0.04888403829380904
# rmse mean: 0.058233812186479814
# r2 mean: 0.8821842228533459

# %% [markdown]
# ### GRU

# %%
re_s = [0.14463189585332023,0.13441049507709296,0.17286387384643254,0.17885303337454264,0.16037136983559158,
       0.13189731357786244,0.17258090836822088,0.17635640146176718,0.15157671888307572,0.09760357180698505]

mae_s = [0.05087362219353954,0.04801018909260918,0.05141120259662405,0.05525465698327599,0.050956078467484546,
        0.04516032618332928,0.05329110246100369,0.05399925541842943,0.04978474916388245,0.048166458096959935]

rmse_s = [0.057361954814965165,0.05561740985780382,0.0587614519510411,0.062074213966666056,0.05804034848833239,
         0.05450758942962783,0.05989477749457402,0.060878999621931794,0.05576265646594736,0.05632881519028171]

r2_s = [0.8852615551326739,0.8949565729381758,0.8812163882514341,0.8636277168010531,0.8792848990922661,
       0.9003424271878042,0.8696059811102479,0.8704258648262573,0.8861576065788455,0.878840685818919]

print(f're mean: {np.array(re_s).mean()}')
print(f'mae mean: {np.array(mae_s).mean()}')
print(f'rmse mean: {np.array(rmse_s).mean()}')
print(f'r2 mean: {np.array(r2_s).mean()}')
# Out:
# re mean: 0.1521145582084891
# mae mean: 0.05069076406571381
# rmse mean: 0.057922821728117115
# r2 mean: 0.8809719697737677

# %% [markdown]
# ## paper_code_1014_卡尔曼滤波_TransformerEncoder_16-16_RCNN_NASA 的 平均值

# %%
re_s = [0.03236493374108053,0.08952444108308762,0.06243397592360875,0.13914341239444558,0.0532360835404856,
        0.06164344772907464,0.15230440792526403,0.23314045433314085,0.06373817828305817,0.2792776005758151]

mae_s = [0.033700417925694594,0.041749470183400236,0.03733641506042391,0.0623148200762621,0.028369794910640844,
         0.03980196674682627,0.050723259549639715,0.05400839513717518,0.03251280415366146,0.10077994845082833]

rmse_s = [0.042380756446916454,0.04901390039747395,0.04525545287129218,0.0708123376272994,0.034664620449905675,
          0.04797741211763809,0.057207940007059734,0.0659469915091076,0.04016971497483447,0.1230232073567362]

r2_s = [0.9179083325268662,0.9124830857320471,0.9247506858962108,0.7892603160104079,0.9335109533679842,
        0.9101338592793824,0.8726388574963395,0.8263253190292386,0.9362969232009921,0.4115282011583852]

print(f're mean: {np.array(re_s).mean()}')
print(f'mae mean: {np.array(mae_s).mean()}')
print(f'rmse mean: {np.array(rmse_s).mean()}')
print(f'r2 mean: {np.array(r2_s).mean()}')
# Out:
# re mean: 0.11668069355290607
# mae mean: 0.04812972921945526
# rmse mean: 0.057645233375826374
# r2 mean: 0.8434836533697853
